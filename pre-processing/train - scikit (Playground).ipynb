# %%
#%matplotlib notebook
# %matplotlib inline

import json
from collections import OrderedDict
import copy
import numpy as np
import matplotlib.pyplot as plt
from _converter import SensorThings2Dict
from _plotter import plot_confusion_matrix

# %%
with open("ABU1.txt") as f:
    data = []
    bad = 0
    for line in f:
        try:
            features = SensorThings2Dict(line)
            data.append(list(features.values()))
        except Exception, e:
            bad+=1
print("Incomplete rows: {}".format(bad))
print("Loaded: {}".format(len(data)))
# Out:
# Incomplete rows: 170
# Loaded: 30768

# %%
from sklearn import preprocessing
data = np.asarray(data)
scaler = preprocessing.StandardScaler().fit(data[:,2:-1])
data[:,2:-1] = scaler.transform(data[:,2:-1])

# %%
# data = np.asarray(data)
# from sklearn.preprocessing import normalize
# data[:,2:-1] = normalize(data[:,2:-1])
#print(data[:,2:-1])
# numerics = data[:,2:-1]
# for n in numerics[data[:,-1]=='True']:
#     plt.plot(n);
mask = np.random.rand(len(data)) < 0.9
train = data[mask]
test = data[~mask]
print("Train Total: {} Good: {} Faulty: {} Ratio: {}".format(len(train), len(train[train[:,-1]=='True']), len(train[train[:,-1]=='False']), float(len(train[train[:,-1]=='False']))/len(train)))
print("Test  Total: {} Good: {} Faulty: {} Ratio: {}".format(len(test), len(test[test[:,-1]=='True']), len(test[test[:,-1]=='False']), float(len(test[test[:,-1]=='False']))/len(train)))
# Out:
# Train Total: 27801 Good: 26186 Faulty: 1615 Ratio: 0.0580914355599
# Test  Total: 2967 Good: 2797 Faulty: 170 Ratio: 0.00611488795367

# %%
""" Balance data """
def balanceData():
    global train
    faulty = train[train[:,-1]=='False']
    not_faulty = train[train[:,-1]=='True']
    train = np.concatenate((not_faulty, np.repeat(faulty, 15, axis=0))) # repeate faulties
    #train = np.concatenate((not_faulty[:len(faulty)*2], faulty))
    print("Train Total: {} Good: {} Faulty: {} Ratio: {}".format(len(train), len(train[train[:,-1]=='True']), len(train[train[:,-1]=='False']), float(len(train[train[:,-1]=='False']))/len(train)))
    train = train[np.random.permutation(train.shape[0])] # shuffle data
balanceData()
# Out:
# Train Total: 50411 Good: 26186 Faulty: 24225 Ratio: 0.480549879987

# %%
train_data = train[:,2:-1].astype(np.float32)
test_data = test[:,2:-1].astype(np.float32)
"""
Quality_OK is mapped to Faultiness
    'False' -> 1 (Faulty)
    'True'  -> 0 (Good)
"""
train_labels = np.array(train[:,-1]=='False').astype(np.int32)
test_labels = np.array(test[:,-1]=='False').astype(np.int32)

# %%
from IPython.display import display, HTML
import pandas as pd

def eval_metrics(expected, predicted):
    print("------------------------- EVALUATION -------------------------")
#     print("Accuracy Score: {}".format(metrics.accuracy_score(expected, predicted)))
    print(metrics.classification_report(expected, predicted))
    print("Confusion Matrix:")
#     print(metrics.confusion_matrix(expected, predicted))
    display(pd.DataFrame(metrics.confusion_matrix(expected, predicted)))
#     print("Kappa Score: {}".format(metrics.cohen_kappa_score(expected, predicted)))
    print("Matthews Correlation Coefficient: {}".format(metrics.matthews_corrcoef(expected, predicted)))
    print("--------------------------------------------------------------")
#     plot_confusion_matrix(metrics.confusion_matrix(expected, predicted),classes=['Good','Faulty'],title='Confusion matrix',normalize=True)
#     plt.show()

# %%
""" MLP """
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

solvers = ['lbfgs', 'sgd', 'adam']
clf = MLPClassifier(solver=solvers[1], alpha=1e-0, hidden_layer_sizes=(50,100,50), random_state=1, 
                    max_iter=1000, verbose=True, tol=1e-10, learning_rate='adaptive')
# %time clf.fit(train_data, train_labels)

eval_metrics(train_labels, clf.predict(train_data))
eval_metrics(test_labels, clf.predict(test_data))
# Out:
# Iteration 1, loss = 1.15854799
# Iteration 2, loss = 1.13791404
# Iteration 3, loss = 1.12084897
# Iteration 4, loss = 1.10545460
# Iteration 5, loss = 1.09102568
# Iteration 6, loss = 1.07735409
# Iteration 7, loss = 1.06412014
# Iteration 8, loss = 1.05123378
# Iteration 9, loss = 1.03870510
# Iteration 10, loss = 1.02639776
# Iteration 11, loss = 1.01433466
# Iteration 12, loss = 1.00240710
# Iteration 13, loss = 0.99056632
# Iteration 14, loss = 0.97883702
# Iteration 15, loss = 0.96716927
# Iteration 16, loss = 0.95555723
# Iteration 17, loss = 0.94384579
# Iteration 18, loss = 0.93207165
# Iteration 19, loss = 0.92020235
# Iteration 20, loss = 0.90819952
# Iteration 21, loss = 0.89587024
# Iteration 22, loss = 0.88345574
# Iteration 23, loss = 0.87091246
# Iteration 24, loss = 0.85830853
# Iteration 25, loss = 0.84567266
# Iteration 26, loss = 0.83292592
# Iteration 27, loss = 0.82007018
# Iteration 28, loss = 0.80742872
# Iteration 29, loss = 0.79460056
# Iteration 30, loss = 0.78196726
# Iteration 31, loss = 0.76953872
# Iteration 32, loss = 0.75752888
# Iteration 33, loss = 0.74572695
# Iteration 34, loss = 0.73417531
# Iteration 35, loss = 0.72297290
# Iteration 36, loss = 0.71199730
# Iteration 37, loss = 0.70155758
# Iteration 38, loss = 0.69111661
# Iteration 39, loss = 0.68090981
# Iteration 40, loss = 0.67089629
# Iteration 41, loss = 0.66098431
# Iteration 42, loss = 0.65150234
# Iteration 43, loss = 0.64245445
# Iteration 44, loss = 0.63340629
# Iteration 45, loss = 0.62470224
# Iteration 46, loss = 0.61633341
# Iteration 47, loss = 0.60812591
# Iteration 48, loss = 0.60016862
# Iteration 49, loss = 0.59317094
# Iteration 50, loss = 0.58535595
# Iteration 51, loss = 0.57863873
# Iteration 52, loss = 0.57205398
# Iteration 53, loss = 0.56581216
# Iteration 54, loss = 0.55986453
# Iteration 55, loss = 0.55426300
# Iteration 56, loss = 0.54914285
# Iteration 57, loss = 0.54390567
# Iteration 58, loss = 0.53898231
# Iteration 59, loss = 0.53429990
# Iteration 60, loss = 0.52954258
# Iteration 61, loss = 0.52532211
# Iteration 62, loss = 0.52099865
# Iteration 63, loss = 0.51714193
# Iteration 64, loss = 0.51294012
# Iteration 65, loss = 0.50924045
# Iteration 66, loss = 0.50557841
# Iteration 67, loss = 0.50224276
# Iteration 68, loss = 0.49829806
# Iteration 69, loss = 0.49506438
# Iteration 70, loss = 0.49186712
# Iteration 71, loss = 0.48838844
# Iteration 72, loss = 0.48597037
# Iteration 73, loss = 0.48278315
# Iteration 74, loss = 0.47996265
# Iteration 75, loss = 0.47739087
# Iteration 76, loss = 0.47368294
# Iteration 77, loss = 0.47176857
# Iteration 78, loss = 0.46905343
# Iteration 79, loss = 0.46663963
# Iteration 80, loss = 0.46434171
# Iteration 81, loss = 0.46214286
# Iteration 82, loss = 0.46060952
# Iteration 83, loss = 0.45810717
# Iteration 84, loss = 0.45617764
# Iteration 85, loss = 0.45385561
# Iteration 86, loss = 0.45167099
# Iteration 87, loss = 0.45006718
# Iteration 88, loss = 0.44766481
# Iteration 89, loss = 0.44596443
# Iteration 90, loss = 0.44391344
# Iteration 91, loss = 0.44263540
# Iteration 92, loss = 0.44101797
# Iteration 93, loss = 0.43874965
# Iteration 94, loss = 0.43756300
# Iteration 95, loss = 0.43586955
# Iteration 96, loss = 0.43403383
# Iteration 97, loss = 0.43249340
# Iteration 98, loss = 0.43095441
# Iteration 99, loss = 0.42878652
# Iteration 100, loss = 0.42761326
# Iteration 101, loss = 0.42611930
# Iteration 102, loss = 0.42470446
# Iteration 103, loss = 0.42342543
# Iteration 104, loss = 0.42228136
# Iteration 105, loss = 0.42110698
# Iteration 106, loss = 0.41920644
# Iteration 107, loss = 0.41866903
# Iteration 108, loss = 0.41736555
# Iteration 109, loss = 0.41601255
# Iteration 110, loss = 0.41501129
# Iteration 111, loss = 0.41390882
# Iteration 112, loss = 0.41486699
# Iteration 113, loss = 0.41199089
# Iteration 114, loss = 0.41129400
# Iteration 115, loss = 0.41065631
# Iteration 116, loss = 0.40955456
# Iteration 117, loss = 0.40858390
# Iteration 118, loss = 0.40743229
# Iteration 119, loss = 0.40681161
# Iteration 120, loss = 0.40536608
# Iteration 121, loss = 0.40473018
# Iteration 122, loss = 0.40402664
# Iteration 123, loss = 0.40267210
# Iteration 124, loss = 0.40286355
# Iteration 125, loss = 0.40177909
# Iteration 126, loss = 0.40063524
# Iteration 127, loss = 0.39957744
# Iteration 128, loss = 0.39943498
# Iteration 129, loss = 0.39870332
# Iteration 130, loss = 0.39829826
# Iteration 131, loss = 0.39726228
# Iteration 132, loss = 0.39711999
# Iteration 133, loss = 0.39574451
# Iteration 134, loss = 0.39544492
# Iteration 135, loss = 0.39397929
# Iteration 136, loss = 0.39372282
# Iteration 137, loss = 0.39336711
# Iteration 138, loss = 0.39286486
# Iteration 139, loss = 0.39171963
# Iteration 140, loss = 0.39193832
# Iteration 141, loss = 0.39112575
# Iteration 142, loss = 0.39008085
# Iteration 143, loss = 0.38924493
# Iteration 144, loss = 0.38841864
# Iteration 145, loss = 0.38908093
# Iteration 146, loss = 0.38840239
# Iteration 147, loss = 0.38968220
# Iteration 148, loss = 0.38674373
# Iteration 149, loss = 0.38663485
# Iteration 150, loss = 0.38649439
# Iteration 151, loss = 0.38570072
# Iteration 152, loss = 0.38488763
# Iteration 153, loss = 0.38479549
# Iteration 154, loss = 0.38414196
# Iteration 155, loss = 0.38352121
# Iteration 156, loss = 0.38279041
# Iteration 157, loss = 0.38266130
# Iteration 158, loss = 0.38157279
# Iteration 159, loss = 0.38129195
# Iteration 160, loss = 0.38066301
# Iteration 161, loss = 0.38130315
# Iteration 162, loss = 0.38030885
# Iteration 163, loss = 0.37969557
# Iteration 164, loss = 0.37912960
# Iteration 165, loss = 0.37967790
# Iteration 166, loss = 0.37848591
# Iteration 167, loss = 0.37808669
# Iteration 168, loss = 0.37786116
# Iteration 169, loss = 0.37754046
# Iteration 170, loss = 0.37647414
# Iteration 171, loss = 0.37685087
# Iteration 172, loss = 0.37619694
# Iteration 173, loss = 0.37590621
# Iteration 174, loss = 0.37572785
# Iteration 175, loss = 0.37520254
# Iteration 176, loss = 0.37510859
# Iteration 177, loss = 0.37409195
# Iteration 178, loss = 0.37374192
# Iteration 179, loss = 0.37320698
# Iteration 180, loss = 0.37298932
# Iteration 181, loss = 0.37296706
# Iteration 182, loss = 0.37276243
# Iteration 183, loss = 0.37181149
# Iteration 184, loss = 0.37155040
# Iteration 185, loss = 0.37113555
# Iteration 186, loss = 0.37077466
# Iteration 187, loss = 0.37052557
# Iteration 188, loss = 0.37111824
# Iteration 189, loss = 0.37063185
# Iteration 190, loss = 0.36980988
# Iteration 191, loss = 0.36973930
# Iteration 192, loss = 0.36879862
# Iteration 193, loss = 0.37029059
# Iteration 194, loss = 0.36853251
# Iteration 195, loss = 0.36794866
# Iteration 196, loss = 0.36832832
# Iteration 197, loss = 0.36777634
# Iteration 198, loss = 0.36726523
# Iteration 199, loss = 0.36736500
# Iteration 200, loss = 0.36704331
# Iteration 201, loss = 0.36664503
# Iteration 202, loss = 0.36619271
# Iteration 203, loss = 0.36658673
# Iteration 204, loss = 0.36603933
# Iteration 205, loss = 0.36526166
# Iteration 206, loss = 0.36615493
# Iteration 207, loss = 0.36484176
# Iteration 208, loss = 0.36548608
# Iteration 209, loss = 0.36497113
# Iteration 210, loss = 0.36504491
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Setting learning rate to 0.000200
# Iteration 211, loss = 0.35830881
# Iteration 212, loss = 0.35662772
# Iteration 213, loss = 0.35607040
# Iteration 214, loss = 0.35595919
# Iteration 215, loss = 0.35599557
# Iteration 216, loss = 0.35563427
# Iteration 217, loss = 0.35570334
# Iteration 218, loss = 0.35548395
# Iteration 219, loss = 0.35549835
# Iteration 220, loss = 0.35544587
# Iteration 221, loss = 0.35550643
# Iteration 222, loss = 0.35529934
# Iteration 223, loss = 0.35526009
# Iteration 224, loss = 0.35531076
# Iteration 225, loss = 0.35506018
# Iteration 226, loss = 0.35521652
# Iteration 227, loss = 0.35511018
# Iteration 228, loss = 0.35521562
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Setting learning rate to 0.000040
# Iteration 229, loss = 0.35330877
# Iteration 230, loss = 0.35312663
# Iteration 231, loss = 0.35310101
# Iteration 232, loss = 0.35309389
# Iteration 233, loss = 0.35303820
# Iteration 234, loss = 0.35302491
# Iteration 235, loss = 0.35299943
# Iteration 236, loss = 0.35300346
# Iteration 237, loss = 0.35296923
# Iteration 238, loss = 0.35296645
# Iteration 239, loss = 0.35295899
# Iteration 240, loss = 0.35294122
# Iteration 241, loss = 0.35292021
# Iteration 242, loss = 0.35294187
# Iteration 243, loss = 0.35289799
# Iteration 244, loss = 0.35291440
# Iteration 245, loss = 0.35289376
# Iteration 246, loss = 0.35287000
# Iteration 247, loss = 0.35286650
# Iteration 248, loss = 0.35287173
# Iteration 249, loss = 0.35284438
# Iteration 250, loss = 0.35281109
# Iteration 251, loss = 0.35282961
# Iteration 252, loss = 0.35283220
# Iteration 253, loss = 0.35281225
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Setting learning rate to 0.000008
# Iteration 254, loss = 0.35242126
# Iteration 255, loss = 0.35238688
# Iteration 256, loss = 0.35236741
# Iteration 257, loss = 0.35236298
# Iteration 258, loss = 0.35235217
# Iteration 259, loss = 0.35235046
# Iteration 260, loss = 0.35234611
# Iteration 261, loss = 0.35234245
# Iteration 262, loss = 0.35233929
# Iteration 263, loss = 0.35233631
# Iteration 264, loss = 0.35233883
# Iteration 265, loss = 0.35233423
# Iteration 266, loss = 0.35233318
# Iteration 267, loss = 0.35233065
# Iteration 268, loss = 0.35232648
# Iteration 269, loss = 0.35232406
# Iteration 270, loss = 0.35232082
# Iteration 271, loss = 0.35232053
# Iteration 272, loss = 0.35232159
# Iteration 273, loss = 0.35231598
# Iteration 274, loss = 0.35231482
# Iteration 275, loss = 0.35231232
# Iteration 276, loss = 0.35231138
# Iteration 277, loss = 0.35231422
# Iteration 278, loss = 0.35230944
# Iteration 279, loss = 0.35230680
# Iteration 280, loss = 0.35230389
# Iteration 281, loss = 0.35230248
# Iteration 282, loss = 0.35230063
# Iteration 283, loss = 0.35229922
# Iteration 284, loss = 0.35229669
# Iteration 285, loss = 0.35229288
# Iteration 286, loss = 0.35229413
# Iteration 287, loss = 0.35228863
# Iteration 288, loss = 0.35228684
# Iteration 289, loss = 0.35228647
# Iteration 290, loss = 0.35228097
# Iteration 291, loss = 0.35228173
# Iteration 292, loss = 0.35228366
# Iteration 293, loss = 0.35227954
# Iteration 294, loss = 0.35227722
# Iteration 295, loss = 0.35227510
# Iteration 296, loss = 0.35227052
# Iteration 297, loss = 0.35226737
# Iteration 298, loss = 0.35226343
# Iteration 299, loss = 0.35226815
# Iteration 300, loss = 0.35226492
# Iteration 301, loss = 0.35226588
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Setting learning rate to 0.000002
# Iteration 302, loss = 0.35217026
# Iteration 303, loss = 0.35216958
# Iteration 304, loss = 0.35216832
# Iteration 305, loss = 0.35216788
# Iteration 306, loss = 0.35216692
# Iteration 307, loss = 0.35216592
# Iteration 308, loss = 0.35216443
# Iteration 309, loss = 0.35216399
# Iteration 310, loss = 0.35216315
# Iteration 311, loss = 0.35216281
# Iteration 312, loss = 0.35216218
# Iteration 313, loss = 0.35216176
# Iteration 314, loss = 0.35216176
# Iteration 315, loss = 0.35216037
# Iteration 316, loss = 0.35216027
# Iteration 317, loss = 0.35215987
# Iteration 318, loss = 0.35215911
# Iteration 319, loss = 0.35215994
# Iteration 320, loss = 0.35215881
# Iteration 321, loss = 0.35215897
# Iteration 322, loss = 0.35215851
# Iteration 323, loss = 0.35215749
# Iteration 324, loss = 0.35215736
# Iteration 325, loss = 0.35215769
# Iteration 326, loss = 0.35215636
# Iteration 327, loss = 0.35215532
# Iteration 328, loss = 0.35215556
# Iteration 329, loss = 0.35215505
# Iteration 330, loss = 0.35215505
# Iteration 331, loss = 0.35215400
# Iteration 332, loss = 0.35215321
# Iteration 333, loss = 0.35215369
# Iteration 334, loss = 0.35215293
# Iteration 335, loss = 0.35215196
# Iteration 336, loss = 0.35215134
# Iteration 337, loss = 0.35215150
# Iteration 338, loss = 0.35215115
# Iteration 339, loss = 0.35215104
# Iteration 340, loss = 0.35215054
# Iteration 341, loss = 0.35215018
# Iteration 342, loss = 0.35215037
# Iteration 343, loss = 0.35214963
# Iteration 344, loss = 0.35214918
# Iteration 345, loss = 0.35214825
# Iteration 346, loss = 0.35214789
# Iteration 347, loss = 0.35214824
# Iteration 348, loss = 0.35214765
# Iteration 349, loss = 0.35214814
# Iteration 350, loss = 0.35214639
# Iteration 351, loss = 0.35214634
# Iteration 352, loss = 0.35214531
# Iteration 353, loss = 0.35214527
# Iteration 354, loss = 0.35214546
# Iteration 355, loss = 0.35214450
# Iteration 356, loss = 0.35214451
# Iteration 357, loss = 0.35214440
# Iteration 358, loss = 0.35214275
# Iteration 359, loss = 0.35214428
# Iteration 360, loss = 0.35214287
# Iteration 361, loss = 0.35214202
# Iteration 362, loss = 0.35214234
# Iteration 363, loss = 0.35214155
# Iteration 364, loss = 0.35214093
# Iteration 365, loss = 0.35214070
# Iteration 366, loss = 0.35214099
# Iteration 367, loss = 0.35214016
# Iteration 368, loss = 0.35213961
# Iteration 369, loss = 0.35213927
# Iteration 370, loss = 0.35213876
# Iteration 371, loss = 0.35213806
# Iteration 372, loss = 0.35213774
# Iteration 373, loss = 0.35213798
# Iteration 374, loss = 0.35213772
# Iteration 375, loss = 0.35213715
# Iteration 376, loss = 0.35213628
# Iteration 377, loss = 0.35213667
# Iteration 378, loss = 0.35213613
# Iteration 379, loss = 0.35213575
# Iteration 380, loss = 0.35213540
# Iteration 381, loss = 0.35213434
# Iteration 382, loss = 0.35213450
# Iteration 383, loss = 0.35213308
# Iteration 384, loss = 0.35213417
# Iteration 385, loss = 0.35213333
# Iteration 386, loss = 0.35213191
# Iteration 387, loss = 0.35213257
# Iteration 388, loss = 0.35213285
# Iteration 389, loss = 0.35213121
# Iteration 390, loss = 0.35213179
# Iteration 391, loss = 0.35213104
# Iteration 392, loss = 0.35213088
# Iteration 393, loss = 0.35213013
# Iteration 394, loss = 0.35212978
# Iteration 395, loss = 0.35212907
# Iteration 396, loss = 0.35212919
# Iteration 397, loss = 0.35212875
# Iteration 398, loss = 0.35212824
# Iteration 399, loss = 0.35212833
# Iteration 400, loss = 0.35212919
# Iteration 401, loss = 0.35212755
# Iteration 402, loss = 0.35212794
# Iteration 403, loss = 0.35212704
# Iteration 404, loss = 0.35212759
# Iteration 405, loss = 0.35212653
# Iteration 406, loss = 0.35212588
# Iteration 407, loss = 0.35212516
# Iteration 408, loss = 0.35212483
# Iteration 409, loss = 0.35212479
# Iteration 410, loss = 0.35212464
# Iteration 411, loss = 0.35212479
# Iteration 412, loss = 0.35212406
# Iteration 413, loss = 0.35212267
# Iteration 414, loss = 0.35212328
# Iteration 415, loss = 0.35212313
# Iteration 416, loss = 0.35212288
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Setting learning rate to 0.000000
# Iteration 417, loss = 0.35210262
# Iteration 418, loss = 0.35210282
# Iteration 419, loss = 0.35210257
# Iteration 420, loss = 0.35210244
# Iteration 421, loss = 0.35210237
# Iteration 422, loss = 0.35210235
# Iteration 423, loss = 0.35210222
# Iteration 424, loss = 0.35210199
# Iteration 425, loss = 0.35210202
# Iteration 426, loss = 0.35210176
# Iteration 427, loss = 0.35210181
# Iteration 428, loss = 0.35210155
# Iteration 429, loss = 0.35210161
# Iteration 430, loss = 0.35210152
# Iteration 431, loss = 0.35210119
# Iteration 432, loss = 0.35210124
# Iteration 433, loss = 0.35210113
# Iteration 434, loss = 0.35210101
# Iteration 435, loss = 0.35210099
# Iteration 436, loss = 0.35210084
# Iteration 437, loss = 0.35210073
# Iteration 438, loss = 0.35210073
# Iteration 439, loss = 0.35210041
# Iteration 440, loss = 0.35210043
# Iteration 441, loss = 0.35210051
# Iteration 442, loss = 0.35210046
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Learning rate too small. Stopping.
# Wall time: 3min 13s
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#           0       0.98      0.88      0.93     26186
#           1       0.89      0.98      0.93     24225
#
# avg / total       0.94      0.93      0.93     50411
#
# Confusion Matrix:
#        0      1
# 0  23129   3057
# 1    405  23820
# Matthews Correlation Coefficient: 0.867794315291
# --------------------------------------------------------------
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#           0       0.96      0.83      0.89      2797
#           1       0.12      0.37      0.18       170
#
# avg / total       0.91      0.81      0.85      2967
#
# Confusion Matrix:
#       0    1
# 0  2333  464
# 1   107   63
# Matthews Correlation Coefficient: 0.124474465705
# --------------------------------------------------------------

# %%
""" Support Vector Machine """
from sklearn.svm import SVC
from sklearn import metrics

kernels = ['linear', 'poly', 'rbf', 'sigmoid']
clf = SVC(random_state=1, kernel=kernels[2], class_weight='balanced', gamma=0.009, degree=5, C=1.5,tol=1e-6)
# %time clf.fit(train_data, train_labels)

eval_metrics(train_labels, clf.predict(train_data))
eval_metrics(test_labels, clf.predict(test_data))
# Out:
# Wall time: 51.5 s
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#           0       0.93      0.85      0.89     10959
#           1       0.85      0.93      0.89      9930
#
# avg / total       0.89      0.89      0.89     20889
#
# Confusion Matrix:
#       0     1
# 0  9361  1598
# 1   735  9195
# Kappa Score: 0.776995392204
# --------------------------------------------------------------
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#           0       0.96      0.81      0.88      1198
#           1       0.12      0.45      0.19        71
#
# avg / total       0.91      0.79      0.84      1269
#
# Confusion Matrix:
#      0    1
# 0  969  229
# 1   39   32
# Kappa Score: 0.114910760294
# --------------------------------------------------------------

# %%
""" OneClassSVM """
from sklearn.svm import OneClassSVM
from sklearn import metrics

kernels = ['linear', 'poly', 'rbf', 'sigmoid']
clf = OneClassSVM(kernel=kernels[1], degree=5, gamma=0.02)
clf.fit(train_data[train_labels==0])

eval_metrics(train_labels*-2+1, clf.predict(train_data))
eval_metrics(test_labels*-2+1, clf.predict(test_data))
# Out:
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#          -1       0.50      0.86      0.63      9930
#           1       0.65      0.23      0.34     10959
#
# avg / total       0.58      0.53      0.48     20889
#
# Confusion Matrix:
#       0     1
# 0  8550  1380
# 1  8450  2509
# Kappa Score: 0.0870613238608
# --------------------------------------------------------------
# ------------------------- EVALUATION -------------------------
#              precision    recall  f1-score   support
#
#          -1       0.05      0.86      0.10        71
#           1       0.92      0.10      0.18      1198
#
# avg / total       0.87      0.14      0.17      1269
#
# Confusion Matrix:
#       0    1
# 0    61   10
# 1  1081  117
# Kappa Score: -0.00533427054613
# --------------------------------------------------------------
